# %%
import pandas as pd

# %%
df = pd.read_excel('2022Ethereum_Full_NoScaling_Vader_Binary_Close-Open_reduced_lagged.xlsx')
df
# Out:
#            Date  Internet_Penetration_USA  Population_USA  GDP_USA  \
# 0    2016-01-03                 85.544421          323689  18425.3
# 1    2016-01-04                 85.544421          323689  18425.3
# 2    2016-01-05                 85.544421          323689  18425.3
# 3    2016-01-06                 85.544421          323689  18425.3
# 4    2016-01-07                 85.544421          323689  18425.3
# ...         ...                       ...             ...      ...
# 2550 2022-12-27                 92.000000          333241  25723.9
# 2551 2022-12-28                 92.000000          333241  25723.9
# 2552 2022-12-29                 92.000000          333241  25723.9
# 2553 2022-12-30                 92.000000          333241  25723.9
# 2554 2022-12-31                 92.000000          333241  25723.9
#
#       Inflation_USA  Gold_Price  Oil_Price  Nasdaq_Change  S&P500_Change  \
# 0               1.4      1060.5      37.04       5.439942         -25.54
# 1               1.4      1060.5      37.04       5.439942         -25.54
# 2               1.4      1075.5      36.76     -26.409668           2.93
# 3               1.4      1078.7      35.97      22.000000         -21.45
# 4               1.4      1092.2      33.97     -46.969726         -42.23
# ...             ...         ...        ...            ...            ...
# 2550            6.5      1797.7      75.89    -108.959961         -14.09
# 2551            6.5      1797.7      75.89    -125.910156         -46.34
# 2552            6.5      1797.7      75.89     156.629883          43.83
# 2553            6.5      1797.7      75.89      98.110352          10.44
# 2554            6.5      1797.7      75.89      98.110352          10.44
#
#       BTC_Change   BTC_Open   BTC_High    BTC_Low  BTC_Close    BTC_Volume  \
# 0              1    433.438    433.743    424.706    429.880  3.117175e+07
# 1              0    430.011    434.517    429.084    433.122  3.715623e+07
# 2              1    433.091    434.182    429.676    431.945  3.669657e+07
# 3              0    431.960    431.960    426.341    430.231  3.357784e+07
# 4              1    429.105    458.766    429.077    458.655  6.315093e+07
# ...          ...        ...        ...        ...        ...           ...
# 2550           1  16842.250  16920.120  16812.370  16919.810  1.188696e+10
# 2551           0  16919.290  16959.850  16642.070  16717.170  1.574858e+10
# 2552           0  16716.400  16768.170  16497.560  16552.570  1.700571e+10
# 2553           1  16552.320  16651.760  16508.680  16642.340  1.447224e+10
# 2554           0  16641.330  16643.430  16408.480  16602.590  1.592916e+10
#
#       BTC_Market_Cap  Tweets_Count  Tweets_Vader_Sentiment  \
# 0       6.461269e+09         13583                0.238774
# 1       6.494453e+09         13691                0.254835
# 2       6.504166e+09         13167                0.248901
# 3       6.471942e+09         15821                0.181530
# 4       6.756367e+09         16689                0.182860
# ...              ...           ...                     ...
# 2550    3.256043e+11         30277                0.118710
# 2551    3.217172e+11         36179                0.093310
# 2552    3.185671e+11         39816                0.097602
# 2553    3.203093e+11         42534                0.084050
# 2554    3.195595e+11         41316                0.099584
#
#       News_Vader_Sentiment  Ethereum_Change
# 0                 0.000000                1
# 1                 0.000000                0
# 2                 0.000000                0
# 3                 0.000000                1
# 4                 0.153550                0
# ...                    ...              ...
# 2550             -0.047619                0
# 2551             -0.035239                0
# 2552             -0.054126                1
# 2553             -0.066367                0
# 2554             -0.052279                0
#
# [2555 rows x 20 columns]

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (20,12))
ax = sns.heatmap(df.corr(), annot=True, linewidths=.5,
                 annot_kws={'fontsize':10, 'fontweight':'bold'})

# %%
import numpy as np

# %%
matrix = np.triu(df.corr())

plt.figure(figsize = (20,12))
ax = sns.heatmap(df.corr(), annot=True, linewidths=.5,
                 annot_kws={'fontsize':10, 'fontweight':'bold'},
                 mask=matrix)
