# %%
import pandas as pd

# %%
df = pd.read_csv('Change_Count.csv')

# %%
df
# Out:
#             Date  Bitcoin_Change  Binance_Change  Cardano_Change  \
# 0     2022-12-31               0             1.0             1.0
# 1     2022-12-30               0             0.0             1.0
# 2     2022-12-29               1             1.0             0.0
# 3     2022-12-28               0             0.0             0.0
# 4     2022-12-27               0             1.0             0.0
# ...          ...             ...             ...             ...
# 2552  2016-01-05               0             NaN             NaN
# 2553  2016-01-04               1             NaN             NaN
# 2554  2016-01-03               0             NaN             NaN
# 2555  2016-01-02               0             NaN             NaN
# 2556  2016-01-01               1             NaN             NaN
#
#       Ethereum_Change  Litecoin_Change  Monero_Change  Stellar_Change  \
# 0                 0.0                1              1               0
# ...

# %%
df['XRP_Change'].value_counts()
# Out:
# 0    1318
# 1    1239
# Name: XRP_Change, dtype: int64
