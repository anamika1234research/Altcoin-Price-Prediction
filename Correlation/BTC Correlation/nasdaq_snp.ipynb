# %%
import pandas as pd

# %%
df = pd.read_excel('S&P500_Regular.xlsx')
df = df.rename(columns={
    'Close*' : 'Close'
})
df = df.drop(columns=['Adj Close**'])
df
# Out:
#            Date     Open     High      Low    Close        Volume  Change
# 0    2016-01-01  2038.20  2038.20  1989.68  2012.66  4.304880e+09  -25.54
# 1    2016-01-02  2038.20  2038.20  1989.68  2012.66  4.304880e+09  -25.54
# 2    2016-01-03  2038.20  2038.20  1989.68  2012.66  4.304880e+09  -25.54
# 3    2016-01-04  2038.20  2038.20  1989.68  2012.66  4.304880e+09  -25.54
# 4    2016-01-05  2013.78  2021.94  2004.17  2016.71  3.706620e+09    2.93
# ...         ...      ...      ...      ...      ...           ...     ...
# 2552 2022-12-27  3843.34  3846.65  3813.22  3829.25  3.030300e+09  -14.09
# 2553 2022-12-28  3829.56  3848.32  3780.78  3783.22  3.083520e+09  -46.34
# 2554 2022-12-29  3805.45  3858.19  3805.45  3849.28  3.003680e+09   43.83
# 2555 2022-12-30  3829.06  3839.85  3800.34  3839.50  2.979870e+09   10.44
# 2556 2022-12-31  3829.06  3839.85  3800.34  3839.50  2.979870e+09   10.44
#
# [2557 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
matrix = np.triu(df.corr())

plt.figure(figsize = (15,9))
ax = sns.heatmap(df.corr(), annot=True, linewidths=.5,
                 annot_kws={'fontsize':10, 'fontweight':'bold'},
                 mask=matrix)
