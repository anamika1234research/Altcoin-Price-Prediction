# %%
pip install pycaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# for numeric handling
import numpy as np
# to handle dataframes
import pandas as pd 
# for plotting
import matplotlib.pyplot as plt

# %%
data = pd.read_excel(r"/content/2022Ethereum_Original_LowCloseRemoved_All_Change_bin.xlsx", na_values='?',index_col=0)
# cheack for data shape
data.shape
# Out:
# (2557, 12)

# %%
# check for the first five observations of the dataset
data.head()
# Out:
#             Gold_Price  Oil_Price  Nasdaq_Change_bin_0day  Nasdaq_Volume  \
# Date
# 2016-01-01      1060.5      37.04                       1     2218420000
# 2016-01-02      1060.5      37.04                       1     2218420000
# 2016-01-03      1060.5      37.04                       1     2218420000
# 2016-01-04      1075.5      36.76                       1     2218420000
# 2016-01-05      1078.7      35.97                       0     1927380000
#
#             S&P500_Change_Bin_0day  S&P500_Volume  BTC_Change_Bin_0day  \
# Date
# 2016-01-01                       0     4304880000                    0
# 2016-01-02                       0     4304880000                    1
# 2016-01-03                       0     4304880000                    0
# 2016-01-04                       0     4304880000                    1
# 2016-01-05                       1     3706620000                    0
#
#               BTC_Volume  Tweets_Count  Tweets_Vader_Sentiment  \
# Date
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
sh = data.shape

# %%
T = sh[0]*0.74 + 1
T = int(T)

# %%
Train = data.iloc[0:T,:]
Test = data.iloc[T:,:]

# %%
# init setup
from pycaret.classification import *
s = setup(data = Train,test_data = Test, target = 'Ethereum_Change', session_id=123)
# Out:
# <style type="text/css">
# #T_5b3c3_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5b3c3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b3c3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5b3c3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b3c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b3c3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5b3c3_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_5b3c3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5b3c3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5b3c3_row1_col1" class="data row1 col1" >Ethereum_Change</td>
#     </tr>
#     <tr>
#       <th id="T_5b3c3_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models(cross_validation=False)
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                              06:16:44
# Status     Fitting Gradient Boosting Classifier
# Estimator          Gradient Boosting Classifier
# <style type="text/css">
# #T_43ac0 th {
#   text-align: left;
# }
# ...

# %%
best_model
